# %%
import requests
import pandas as pd
url = "https://www.omdbapi.com/"
api_key ="86a249ab"
#parameter for the get request
params = {
    "apikey": api_key,
    "s": "star wars"
}
response = requests.get(url, params=params)
movies_list = []
if response.status_code == 200:
    results = response.json()
    for movie in results['Search']:
        movie_detail = {
            "Movie Title": movie["Title"],
            "Movie Year": movie["Year"],
            "Movie ID": movie["imdbID"],
            "Movie Type": movie["Type"],
            "Movie Poster": movie["Poster"],
        }
        #append to movies_list
        movies_list.append(movie_detail)
    

else:
    print("error:", response.status_code)
#create pandas dataframe
df = pd.DataFrame(movies_list)
df
# Out:
#                                       Movie Title Movie Year   Movie ID  \
# 0              Star Wars: Episode IV - A New Hope       1977  tt0076759
# 1  Star Wars: Episode V - The Empire Strikes Back       1980  tt0080684
# 2      Star Wars: Episode VI - Return of the Jedi       1983  tt0086190
# 3      Star Wars: Episode VII - The Force Awakens       2015  tt2488496
# 4       Star Wars: Episode I - The Phantom Menace       1999  tt0120915
# 5    Star Wars: Episode III - Revenge of the Sith       2005  tt0121766
# 6    Star Wars: Episode II - Attack of the Clones       2002  tt0121765
# 7                    Rogue One: A Star Wars Story       2016  tt3748528
# 8         Star Wars: Episode VIII - The Last Jedi       2017  tt2527336
# 9   Star Wars: Episode IX - The Rise of Skywalker       2019  tt2527338
#
#   Movie Type                                       Movie Poster
# 0      movie  https://m.media-amazon.com/images/M/MV5BOGUwMD...
# 1      movie  https://m.media-amazon.com/images/M/MV5BMTkxNG...
# 2      movie  https://m.media-amazon.com/images/M/MV5BNWEwOT...
# 3      movie  https://m.media-amazon.com/images/M/MV5BOTAzOD...
# 4      movie  https://m.media-amazon.com/images/M/MV5BODVhNG...
# 5      movie  https://m.media-amazon.com/images/M/MV5BNTc4MT...
# 6      movie  https://m.media-amazon.com/images/M/MV5BNTgxMj...
# 7      movie  https://m.media-amazon.com/images/M/MV5BMjEwMz...
# 8      movie  https://m.media-amazon.com/images/M/MV5BMjQ1Mz...
# 9      movie  https://m.media-amazon.com/images/M/MV5BODg5ZT...
