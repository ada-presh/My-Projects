# %% [markdown]
# <a href="https://colab.research.google.com/github/ada-presh/My-Projects/blob/main/movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
url = "https://www.omdbapi.com/"
api_key ="86a249ab"
#parameter for the get request
params = {
    "apikey": api_key,
    "s": "avengers"
}
response = requests.get(url, params=params)
movies_list = []
if response.status_code == 200:
    results = response.json()
    for movie in results['Search']:
        movie_detail = {
            "Movie Title": movie["Title"],
            "Movie Year": movie["Year"],
            "Movie ID": movie["imdbID"],
            "Movie Type": movie["Type"],
            "Movie Poster": movie["Poster"],
        }
        #append to movies_list
        movies_list.append(movie_detail)


else:
    print("error:", response.status_code)
#create pandas dataframe
df = pd.DataFrame(movies_list)
df
# Out:
#                               Movie Title Movie Year   Movie ID Movie Type  \
# 0                            The Avengers       2012  tt0848228      movie
# 1                       Avengers: Endgame       2019  tt4154796      movie
# 2                  Avengers: Infinity War       2018  tt4154756      movie
# 3                 Avengers: Age of Ultron       2015  tt2395427      movie
# 4                            The Avengers       1998  tt0118661      movie
# 5  The Avengers: Earth's Mightiest Heroes  2010–2024  tt1626038     series
# 6            Ultimate Avengers: The Movie       2006  tt0491703      movie
# 7                            The Avengers  1961–1969  tt0054518     series
# 8                    Ultimate Avengers II       2006  tt0803093      movie
# 9                       Avengers Assemble  2012–2019  tt2455546     series
#
#                                         Movie Poster
# 0  https://m.media-amazon.com/images/M/MV5BNGE0YT...
# ...
